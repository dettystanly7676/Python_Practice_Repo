# %% [markdown]
# <a href="https://colab.research.google.com/github/dettystanly7676/Python_Practice_Repo/blob/main/PRACTICE_EXERCISES_ON_PYTHON_BASICS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Write a Python program to accept a string value from the user and display
# the count of each character in that string. Sample input: Enter a string
# value: assembly Sample output: a=1, s=2, e=1, m=1, b=1, l=1, y=1

# %%
word = input('Enter a string: ')
letter_list =[]
dupli_list = []

for letter in word:
  letter_list.append(letter)
  # print(letter_list)

for letter in letter_list:
  if letter not in dupli_list:
   print(letter,'=',letter_list.count(letter))
   dupli_list.append(letter)
# Out:
# Enter a string: assembly
# a = 1
# s = 2
# e = 1
# m = 1
# b = 1
# l = 1
# y = 1

# %% [markdown]
# 2. Write a Python function to find the maximum of three numbers Sample
# input: 34,12,7 Sample output: 34

# %%
def max_of_three(num1,num2,num3):
  return max(num1,num2,num3)

num1 = int(input('Enter first number: '))
num2 = int(input('Enter second number: '))
num3 = int(input('Enter third4 number: '))
print(max_of_three(num1,num2,num3),'is the greatest number')
# Out:
# Enter first number: 33
# Enter second number: 55
# Enter third4 number: 90
# 90 is the greatest number

# %% [markdown]
# 3. Write a Python function called exponent(base,exp) that returns an
# integer value of base raises to the power of exp. Sample input: Enter the
# base: 2 Enter the exponent: 3 Sample output: 8

# %%
def exponent(base,exp):
  return base**exp

base_number = int(input('Enter the base number: '))
exp_number = int(input('Enter the exponent number: '))
print(base_number,'to the power',exp_number,'is',exponent(base_number,exp_number))
# Out:
# Enter the base number: 2
# Enter the exponent number: 4
# 2 to the power 4 is 16

# %% [markdown]
# 4. Write a Python function that takes a positive integer and returns the sum
# of the cube of all the positive integers smaller than the specified number.
# Sample input: 4 Sample output: 36.

# %%
def sum_of_integers(n):
  result = 1
  total = 0
  for number in range(1,n):
    result = number ** 3
    total += result
  return total

number = int(input('Enter a number: '))
print('Sum of the cube of all the positive integers smaller than',number,'is',sum_of_integers(number))
# Out:
# Enter a number: 4
# Sum of the cube of all the positive integers smaller than 4 is 36

# %% [markdown]
# 5. Write a Python program which iterates from 1 to 10. For multiples of 2,
# print “Fizz” instead of the number and for the multiples of 5, print “Buzz”.
# For numbers which are multiples of both 2 and 5, print “FizzBuzz”.
# Sample input: numbers from 1 to 10 Sample output: 1 Fizz 3 Fizz Buzz
# Fizz 7 Fizz 9 FizzBuzz

# %%
for i in range(1,11):
  if i%2 == 0:
    print('Fizz')
  if i%5 == 0:
    print('Buzz')
  if i%2 == 0 and i%5 ==0:
    print('FizzBuzz')
# Out:
# Fizz
# Fizz
# Buzz
# Fizz
# Fizz
# Fizz
# Buzz
# FizzBuzz

# %% [markdown]
# 6. Write a Python program to find the most frequent item in a list of
# numbers. Sample input: 2, 3, 4, 2, 5, 2 Sample output: 2

# %%
sample_list = [2,3,4,2,5,2]
count = 0
max_count = 0

for item in sample_list:
  if sample_list.count(item) > count:
    max_count = sample_list.count(item)
    final_item = item

print('Most frequent item in the list is',final_item)
# Out:
# Most frequent item in the list is 2

# %% [markdown]
# 7. Write a Python program to find the sum of squares of the numbers in a
# list. Sample input: 2,1,3,1 Sample output: 15

# %%
inp_list = [2,1,3,1]
total = 0

for item in inp_list:
  total += item ** 2
print('Sum of squares of the numbers in the list',inp_list,'is',total)
# Out:
# Sum of squares of the numbers in the list [2, 1, 3, 1] is 15

# %% [markdown]
# 8. Write a Python program using for loop that will iterate from 1 to 15. For
# each iteration, check if the current number is odd or even, and display the
# message to the screen as odd or even. Sample input: 1….15 Sample
# output: 1-odd 2-even …. 15-odd

# %%
for n in range(1,16):
  if n%2 == 0:
    print(n,'- even')
  else:
    print(n,'- odd')
# Out:
# 1 - odd
# 2 - even
# 3 - odd
# 4 - even
# 5 - odd
# 6 - even
# 7 - odd
# 8 - even
# 9 - odd
# 10 - even
# 11 - odd
# 12 - even
# 13 - odd
# 14 - even
# 15 - odd

# %% [markdown]
# 9. Write a Python program to convert temperatures to and from Celsius
# Fahrenheit. [Formula: c/5=f-32/9 where c=temperature in Celsius and f=
# temperature in Fahrenheit.] Sample input: Temperature in Fahrenheit
# =41 Sample output: Temperature in Celsius =5

# %%
ftemp = int(input('Enter a temperature in Fahrenheit: '))
ctemp = (ftemp - 32) * 5 / 9

print('Temperature in Celsius is',ctemp)
# Out:
# Enter a temperature in Fahrenheit: 41
# Temperature in Celsius is 5.0

# %% [markdown]
# 10. Write a Python function to calculate the factorial of a number (a
# nonnegative integer). The function accepts the number as an argument.
# Sample input: 3 Sample output: 6

# %%
def fact(n):
  if n == 1 or n == 0:
    return 1
  else:
    return n * fact(n - 1)

number = int(input('Enter a number: '))

if number < 0:
  print('Invalid input')
else:
  result = fact(number)
  print('Factorial of',number,'is',result)
# Out:
# Enter a number: 3
# Factorial of 3 is 6
